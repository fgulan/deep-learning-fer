# %%
from dataset import Dataset
from run_model import run_language_model

# %%
# Prepare dataset
dataset = Dataset(sequence_length=30, batch_size=32)
dataset.preprocess("data/selected_conversations.txt")
dataset.create_minibatches()

# %%
# Start learning
run_language_model(dataset, 200, sequence_length=dataset.sequence_length, seed="HAN:\nIs that good or bad?\n\n")
# Out:
# ==== batch: 0/616, bch loss: 129.4490242621818, epoch: 1/200, avg loss: 12.944902426218182 ====
# ...
# HAN:
# Is that good or bad?
#
# ,tI
# WIz
# VFu2EkH5YYNF'2K
# ,VEI
# TltI0:,`E
# zTIMI
# lIcHHD6
# D:zXt
#
# YDI',8pV`4y6tHS5KikZVTuCCB,EXXTbDz2UI5IzV2ET
# IWI
# V`ZG2ENLz2.pXER,MG
# I0,VT
#
# l`k,vbN
# fGKEl4DVE`TyT:2b
# IVDlXVFV'`f5x
# ...
# ==== batch: 100/616, bch loss: 83.63001726544438, epoch: 1/200, avg loss: 83.59487882672569 ====
# ...
# HAN:
# Is that good or bad?
#
# G, Ihefoutheuu E.l. chhali spyit yrttlnnhe bed p stea louse mn. Iol toey ce thenn ,hl erots toaetk sy stee s.
#
# SSNl ir?th..
# OA0,:
# UheaarhetIgivot coaov',eeto.?
# :Euru ,olr La
# ...
# ==== batch: 200/616, bch loss: 82.07931321172106, epoch: 1/200, avg loss: 83.10973842518248 ====
# ...
# HAN:
# Is that good or bad?
#
# ERE:DV lin dt tphe m?
# .
# I.s.AJTQ
# RNRTRN0Nz:
# He lvike EI or wme nay cosr I` wn ran'  ndlnME:
#  yf inkcg, a?
#
#
# ER:
# He parr  uth s twy aalam thavbimee meL wn nt ercre shane puge
# ...

# %%
run_language_model(dataset, 100, sequence_length=dataset.sequence_length, learning_rate=1e-1, seed="JEFFREY:\nHi. Hi Sandy. I'm sorry to bother you, but I've got to talk to you.\n\n")
# Out:
# ==== batch: 0/616, bch loss: 128.90396632153954, epoch: 1/100, avg loss: 12.890396632153955 ====
# ...
# JEFFREY:
# Hi. Hi Sandy. I'm sorry to bother you, but I've got to talk to you.
#
#  Zw7J`fPzH1Kk21fTr0mR    v Y.l'lC40Z MXoBf9:8cQxZ5R8
# ??Y.AJsmvd4xl m Y7 LR5'c6Y!:6bROu
# I8SmYng.wvevv, tm 6o7!o764GZRFJR2Q1
# ...
# ==== batch: 100/616, bch loss: 88.32463876553058, epoch: 1/100, avg loss: 92.77162583847033 ====
# ...
# JEFFREY:
# Hi. Hi Sandy. I'm sorry to bother you, but I've got to talk to you.
#
# rale. . Tsulk. G t?
# rO menil lwt a goh..'E inl'lrophosali youi lnaul s tt nkeh.
# nl ky lhy lte o.u. cmu 'a..
#
# wbe  onlbrlto
# ...
# ==== batch: 200/616, bch loss: 75.59913869520749, epoch: 1/100, avg loss: 76.42779020764138 ====
# ...
# JEFFREY:
# Hi. Hi Sandy. I'm sorry to bother you, but I've got to talk to you.
#
#
# Minaw'w. whenf WengYte ele?
#
# RILS:
# Whaptser, tAl ktot es tl srrt tlend I il pre, yoc g ll?
# n to lht irse, connte nhtsth i
# ...
