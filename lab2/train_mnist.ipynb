# %%
import time
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import nn
import layers

DATA_DIR = './mnist/'
SAVE_DIR = "./out/"

config = {}
config['max_epochs'] = 4
config['batch_size'] = 50
config['save_dir'] = SAVE_DIR
config['lr_policy'] = {1:{'lr':1e-1}, 3:{'lr':1e-2}, 5:{'lr':1e-3}, 7:{'lr':1e-4}}

# %%
np.random.seed(int(time.time() * 1e6) % 2**31)
dataset = input_data.read_data_sets(DATA_DIR, one_hot=True)
train_x = dataset.train.images
train_x = train_x.reshape([-1, 1, 28, 28])
train_y = dataset.train.labels
valid_x = dataset.validation.images
valid_x = valid_x.reshape([-1, 1, 28, 28])
valid_y = dataset.validation.labels
test_x = dataset.test.images
test_x = test_x.reshape([-1, 1, 28, 28])
test_y = dataset.test.labels
train_mean = train_x.mean()
train_x -= train_mean
valid_x -= train_mean
test_x -= train_mean
# Out:
# Extracting ./mnist/train-images-idx3-ubyte.gz
# Extracting ./mnist/train-labels-idx1-ubyte.gz
# Extracting ./mnist/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/t10k-labels-idx1-ubyte.gz

# %%
net = []
inputs = np.random.randn(config['batch_size'], 1, 28, 28)
net += [layers.Convolution(inputs, 16, 5, "conv1")]
net += [layers.MaxPooling(net[-1], "pool1")]
net += [layers.ReLU(net[-1], "relu1")]
net += [layers.Convolution(net[-1], 32, 5, "conv2")]
net += [layers.MaxPooling(net[-1], "pool2")]
net += [layers.ReLU(net[-1], "relu2")]
# out = 7x7
net += [layers.Flatten(net[-1], "flatten3")]
net += [layers.FC(net[-1], 512, "fc3")]
net += [layers.ReLU(net[-1], "relu3")]
net += [layers.FC(net[-1], 10, "logits")]

loss = layers.SoftmaxCrossEntropyWithLogits()

# %%
nn.train(train_x, train_y, valid_x, valid_y, net, loss, config)
nn.evaluate("Test", test_x, test_y, net, loss, config)
# Out:
# epoch 1, step 0/55000, batch loss = 2.46
# /Users/filipgulan/.virtualenvs/deep-learning/lib/python3.5/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# epoch 1, step 250/55000, batch loss = 1.78
# epoch 1, step 500/55000, batch loss = 1.47
# epoch 1, step 750/55000, batch loss = 1.20
# epoch 1, step 1000/55000, batch loss = 0.67
# epoch 1, step 1250/55000, batch loss = 0.88
# epoch 1, step 1500/55000, batch loss = 0.49
# epoch 1, step 1750/55000, batch loss = 0.51
# epoch 1, step 2000/55000, batch loss = 0.54
# epoch 1, step 2250/55000, batch loss = 0.45
# epoch 1, step 2500/55000, batch loss = 0.48
# Train accuracy = 67.18
# epoch 1, step 2750/55000, batch loss = 0.46
# epoch 1, step 3000/55000, batch loss = 0.79
# epoch 1, step 3250/55000, batch loss = 0.25
# epoch 1, step 3500/55000, batch loss = 0.35
# epoch 1, step 3750/55000, batch loss = 0.10
# epoch 1, step 4000/55000, batch loss = 0.15
# epoch 1, step 4250/55000, batch loss = 0.30
# epoch 1, step 4500/55000, batch loss = 0.29
# epoch 1, step 4750/55000, batch loss = 0.22
# epoch 1, step 5000/55000, batch loss = 0.26
# Train accuracy = 78.95
# epoch 1, step 5250/55000, batch loss = 0.27
# epoch 1, step 5500/55000, batch loss = 0.48
# epoch 1, step 5750/55000, batch loss = 0.21
# epoch 1, step 6000/55000, batch loss = 0.18
# epoch 1, step 6250/55000, batch loss = 0.24
# epoch 1, step 6500/55000, batch loss = 0.08
# epoch 1, step 6750/55000, batch loss = 0.19
# epoch 1, step 7000/55000, batch loss = 0.10
# epoch 1, step 7250/55000, batch loss = 0.42
# epoch 1, step 7500/55000, batch loss = 0.22
# Train accuracy = 83.81
# epoch 1, step 7750/55000, batch loss = 0.25
# epoch 1, step 8000/55000, batch loss = 0.14
# epoch 1, step 8250/55000, batch loss = 0.18
# epoch 1, step 8500/55000, batch loss = 0.07
# epoch 1, step 8750/55000, batch loss = 0.33
# epoch 1, step 9000/55000, batch loss = 0.11
# epoch 1, step 9250/55000, batch loss = 0.14
# epoch 1, step 9500/55000, batch loss = 0.08
# epoch 1, step 9750/55000, batch loss = 0.16
# epoch 1, step 10000/55000, batch loss = 0.43
# Train accuracy = 86.57
# epoch 1, step 10250/55000, batch loss = 0.17
# epoch 1, step 10500/55000, batch loss = 0.13
# epoch 1, step 10750/55000, batch loss = 0.21
# epoch 1, step 11000/55000, batch loss = 0.08
# epoch 1, step 11250/55000, batch loss = 0.07
# epoch 1, step 11500/55000, batch loss = 0.16
# epoch 1, step 11750/55000, batch loss = 0.04
# epoch 1, step 12000/55000, batch loss = 0.15
# epoch 1, step 12250/55000, batch loss = 0.14
# epoch 1, step 12500/55000, batch loss = 0.13
# Train accuracy = 88.33
# epoch 1, step 12750/55000, batch loss = 0.21
# epoch 1, step 13000/55000, batch loss = 0.06
# epoch 1, step 13250/55000, batch loss = 0.04
# epoch 1, step 13500/55000, batch loss = 0.17
# epoch 1, step 13750/55000, batch loss = 0.11
# epoch 1, step 14000/55000, batch loss = 0.14
# epoch 1, step 14250/55000, batch loss = 0.27
# epoch 1, step 14500/55000, batch loss = 0.04
# epoch 1, step 14750/55000, batch loss = 0.22
# epoch 1, step 15000/55000, batch loss = 0.04
# Train accuracy = 89.65
# epoch 1, step 15250/55000, batch loss = 0.06
# epoch 1, step 15500/55000, batch loss = 0.22
# epoch 1, step 15750/55000, batch loss = 0.06
# epoch 1, step 16000/55000, batch loss = 0.18
# epoch 1, step 16250/55000, batch loss = 0.07
# epoch 1, step 16500/55000, batch loss = 0.29
# epoch 1, step 16750/55000, batch loss = 0.11
# epoch 1, step 17000/55000, batch loss = 0.02
# epoch 1, step 17250/55000, batch loss = 0.05
# epoch 1, step 17500/55000, batch loss = 0.09
# Train accuracy = 90.55
# epoch 1, step 17750/55000, batch loss = 0.07
# epoch 1, step 18000/55000, batch loss = 0.14
# epoch 1, step 18250/55000, batch loss = 0.14
# epoch 1, step 18500/55000, batch loss = 0.07
# epoch 1, step 18750/55000, batch loss = 0.04
# epoch 1, step 19000/55000, batch loss = 0.15
# epoch 1, step 19250/55000, batch loss = 0.03
# epoch 1, step 19500/55000, batch loss = 0.12
# epoch 1, step 19750/55000, batch loss = 0.05
# epoch 1, step 20000/55000, batch loss = 0.06
# Train accuracy = 91.33
# epoch 1, step 20250/55000, batch loss = 0.11
# epoch 1, step 20500/55000, batch loss = 0.14
# epoch 1, step 20750/55000, batch loss = 0.11
# epoch 1, step 21000/55000, batch loss = 0.07
# epoch 1, step 21250/55000, batch loss = 0.09
# epoch 1, step 21500/55000, batch loss = 0.13
# epoch 1, step 21750/55000, batch loss = 0.16
# epoch 1, step 22000/55000, batch loss = 0.12
# epoch 1, step 22250/55000, batch loss = 0.01
# epoch 1, step 22500/55000, batch loss = 0.07
# Train accuracy = 91.93
# epoch 1, step 22750/55000, batch loss = 0.11
# epoch 1, step 23000/55000, batch loss = 0.03
# epoch 1, step 23250/55000, batch loss = 0.08
# epoch 1, step 23500/55000, batch loss = 0.08
# epoch 1, step 23750/55000, batch loss = 0.01
# epoch 1, step 24000/55000, batch loss = 0.30
# epoch 1, step 24250/55000, batch loss = 0.17
# epoch 1, step 24500/55000, batch loss = 0.11
# epoch 1, step 24750/55000, batch loss = 0.08
# epoch 1, step 25000/55000, batch loss = 0.13
# Train accuracy = 92.46
# epoch 1, step 25250/55000, batch loss = 0.02
# epoch 1, step 25500/55000, batch loss = 0.02
# epoch 1, step 25750/55000, batch loss = 0.04
# epoch 1, step 26000/55000, batch loss = 0.12
# epoch 1, step 26250/55000, batch loss = 0.07
# epoch 1, step 26500/55000, batch loss = 0.07
# epoch 1, step 26750/55000, batch loss = 0.16
# epoch 1, step 27000/55000, batch loss = 0.10
# epoch 1, step 27250/55000, batch loss = 0.07
# epoch 1, step 27500/55000, batch loss = 0.01
# Train accuracy = 92.91
# epoch 1, step 27750/55000, batch loss = 0.06
# epoch 1, step 28000/55000, batch loss = 0.02
# epoch 1, step 28250/55000, batch loss = 0.09
# epoch 1, step 28500/55000, batch loss = 0.23
# epoch 1, step 28750/55000, batch loss = 0.06
# epoch 1, step 29000/55000, batch loss = 0.04
# epoch 1, step 29250/55000, batch loss = 0.03
# epoch 1, step 29500/55000, batch loss = 0.03
# epoch 1, step 29750/55000, batch loss = 0.12
# epoch 1, step 30000/55000, batch loss = 0.08
# Train accuracy = 93.26
# epoch 1, step 30250/55000, batch loss = 0.08
# epoch 1, step 30500/55000, batch loss = 0.11
# epoch 1, step 30750/55000, batch loss = 0.02
# epoch 1, step 31000/55000, batch loss = 0.21
# epoch 1, step 31250/55000, batch loss = 0.02
# epoch 1, step 31500/55000, batch loss = 0.10
# epoch 1, step 31750/55000, batch loss = 0.01
# epoch 1, step 32000/55000, batch loss = 0.04
# epoch 1, step 32250/55000, batch loss = 0.00
# epoch 1, step 32500/55000, batch loss = 0.02
# Train accuracy = 93.63
# epoch 1, step 32750/55000, batch loss = 0.03
# epoch 1, step 33000/55000, batch loss = 0.02
# epoch 1, step 33250/55000, batch loss = 0.13
# epoch 1, step 33500/55000, batch loss = 0.05
# epoch 1, step 33750/55000, batch loss = 0.04
# epoch 1, step 34000/55000, batch loss = 0.12
# epoch 1, step 34250/55000, batch loss = 0.07
# epoch 1, step 34500/55000, batch loss = 0.05
# epoch 1, step 34750/55000, batch loss = 0.02
# epoch 1, step 35000/55000, batch loss = 0.02
# Train accuracy = 93.93
# epoch 1, step 35250/55000, batch loss = 0.05
# epoch 1, step 35500/55000, batch loss = 0.02
# epoch 1, step 35750/55000, batch loss = 0.13
# epoch 1, step 36000/55000, batch loss = 0.11
# epoch 1, step 36250/55000, batch loss = 0.12
# epoch 1, step 36500/55000, batch loss = 0.03
# epoch 1, step 36750/55000, batch loss = 0.14
# epoch 1, step 37000/55000, batch loss = 0.05
# epoch 1, step 37250/55000, batch loss = 0.02
# epoch 1, step 37500/55000, batch loss = 0.11
# Train accuracy = 94.22
# epoch 1, step 37750/55000, batch loss = 0.04
# epoch 1, step 38000/55000, batch loss = 0.07
# epoch 1, step 38250/55000, batch loss = 0.14
# epoch 1, step 38500/55000, batch loss = 0.04
# epoch 1, step 38750/55000, batch loss = 0.01
# epoch 1, step 39000/55000, batch loss = 0.10
# epoch 1, step 39250/55000, batch loss = 0.08
# epoch 1, step 39500/55000, batch loss = 0.18
# epoch 1, step 39750/55000, batch loss = 0.03
# epoch 1, step 40000/55000, batch loss = 0.02
# Train accuracy = 94.44
# epoch 1, step 40250/55000, batch loss = 0.09
# epoch 1, step 40500/55000, batch loss = 0.01
# epoch 1, step 40750/55000, batch loss = 0.08
# epoch 1, step 41000/55000, batch loss = 0.10
# epoch 1, step 41250/55000, batch loss = 0.10
# epoch 1, step 41500/55000, batch loss = 0.17
# epoch 1, step 41750/55000, batch loss = 0.10
# epoch 1, step 42000/55000, batch loss = 0.05
# epoch 1, step 42250/55000, batch loss = 0.02
# epoch 1, step 42500/55000, batch loss = 0.08
# Train accuracy = 94.63
# epoch 1, step 42750/55000, batch loss = 0.03
# epoch 1, step 43000/55000, batch loss = 0.11
# epoch 1, step 43250/55000, batch loss = 0.05
# epoch 1, step 43500/55000, batch loss = 0.07
# epoch 1, step 43750/55000, batch loss = 0.14
# epoch 1, step 44000/55000, batch loss = 0.05
# epoch 1, step 44250/55000, batch loss = 0.07
# epoch 1, step 44500/55000, batch loss = 0.03
# epoch 1, step 44750/55000, batch loss = 0.12
# epoch 1, step 45000/55000, batch loss = 0.02
# Train accuracy = 94.81
# epoch 1, step 45250/55000, batch loss = 0.04
# epoch 1, step 45500/55000, batch loss = 0.02
# epoch 1, step 45750/55000, batch loss = 0.03
# epoch 1, step 46000/55000, batch loss = 0.01
# epoch 1, step 46250/55000, batch loss = 0.13
# epoch 1, step 46500/55000, batch loss = 0.07
# epoch 1, step 46750/55000, batch loss = 0.01
# epoch 1, step 47000/55000, batch loss = 0.06
# epoch 1, step 47250/55000, batch loss = 0.21
# epoch 1, step 47500/55000, batch loss = 0.05
# Train accuracy = 94.99
# epoch 1, step 47750/55000, batch loss = 0.11
# epoch 1, step 48000/55000, batch loss = 0.03
# epoch 1, step 48250/55000, batch loss = 0.03
# epoch 1, step 48500/55000, batch loss = 0.03
# epoch 1, step 48750/55000, batch loss = 0.08
# epoch 1, step 49000/55000, batch loss = 0.18
# epoch 1, step 49250/55000, batch loss = 0.01
# epoch 1, step 49500/55000, batch loss = 0.09
# epoch 1, step 49750/55000, batch loss = 0.05
# epoch 1, step 50000/55000, batch loss = 0.04
# Train accuracy = 95.14
# epoch 1, step 50250/55000, batch loss = 0.01
# epoch 1, step 50500/55000, batch loss = 0.09
# epoch 1, step 50750/55000, batch loss = 0.02
# epoch 1, step 51000/55000, batch loss = 0.02
# epoch 1, step 51250/55000, batch loss = 0.01
# epoch 1, step 51500/55000, batch loss = 0.04
# epoch 1, step 51750/55000, batch loss = 0.02
# epoch 1, step 52000/55000, batch loss = 0.06
# epoch 1, step 52250/55000, batch loss = 0.06
# epoch 1, step 52500/55000, batch loss = 0.01
# Train accuracy = 95.28
# epoch 1, step 52750/55000, batch loss = 0.03
# epoch 1, step 53000/55000, batch loss = 0.14
# epoch 1, step 53250/55000, batch loss = 0.04
# epoch 1, step 53500/55000, batch loss = 0.00
# epoch 1, step 53750/55000, batch loss = 0.12
# epoch 1, step 54000/55000, batch loss = 0.02
# epoch 1, step 54250/55000, batch loss = 0.01
# epoch 1, step 54500/55000, batch loss = 0.01
# epoch 1, step 54750/55000, batch loss = 0.06
# Train accuracy = 95.42
#
# Running evaluation:  Validation
# Validation accuracy = 97.70
# Validation avg loss = 0.08
#
# epoch 2, step 0/55000, batch loss = 0.04
# epoch 2, step 250/55000, batch loss = 0.05
# epoch 2, step 500/55000, batch loss = 0.02
# epoch 2, step 750/55000, batch loss = 0.01
# epoch 2, step 1000/55000, batch loss = 0.04
# epoch 2, step 1250/55000, batch loss = 0.17
# epoch 2, step 1500/55000, batch loss = 0.10
# epoch 2, step 1750/55000, batch loss = 0.01
# epoch 2, step 2000/55000, batch loss = 0.02
# epoch 2, step 2250/55000, batch loss = 0.05
# epoch 2, step 2500/55000, batch loss = 0.02
# Train accuracy = 98.39
# epoch 2, step 2750/55000, batch loss = 0.05
# epoch 2, step 3000/55000, batch loss = 0.05
# epoch 2, step 3250/55000, batch loss = 0.12
# epoch 2, step 3500/55000, batch loss = 0.13
# epoch 2, step 3750/55000, batch loss = 0.05
# epoch 2, step 4000/55000, batch loss = 0.02
# epoch 2, step 4250/55000, batch loss = 0.02
# epoch 2, step 4500/55000, batch loss = 0.06
# epoch 2, step 4750/55000, batch loss = 0.05
# epoch 2, step 5000/55000, batch loss = 0.09
# Train accuracy = 98.42
# epoch 2, step 5250/55000, batch loss = 0.02
# epoch 2, step 5500/55000, batch loss = 0.04
# epoch 2, step 5750/55000, batch loss = 0.02
# epoch 2, step 6000/55000, batch loss = 0.00
# epoch 2, step 6250/55000, batch loss = 0.05
# epoch 2, step 6500/55000, batch loss = 0.01
# epoch 2, step 6750/55000, batch loss = 0.01
# epoch 2, step 7000/55000, batch loss = 0.01
# epoch 2, step 7250/55000, batch loss = 0.04
# epoch 2, step 7500/55000, batch loss = 0.04
# Train accuracy = 98.49
# epoch 2, step 7750/55000, batch loss = 0.03
# epoch 2, step 8000/55000, batch loss = 0.08
# epoch 2, step 8250/55000, batch loss = 0.01
# epoch 2, step 8500/55000, batch loss = 0.01
# epoch 2, step 8750/55000, batch loss = 0.07
# epoch 2, step 9000/55000, batch loss = 0.01
# epoch 2, step 9250/55000, batch loss = 0.05
# epoch 2, step 9500/55000, batch loss = 0.00
# epoch 2, step 9750/55000, batch loss = 0.01
# epoch 2, step 10000/55000, batch loss = 0.01
# Train accuracy = 98.48
# epoch 2, step 10250/55000, batch loss = 0.01
# epoch 2, step 10500/55000, batch loss = 0.07
# epoch 2, step 10750/55000, batch loss = 0.09
# epoch 2, step 11000/55000, batch loss = 0.03
# epoch 2, step 11250/55000, batch loss = 0.02
# epoch 2, step 11500/55000, batch loss = 0.02
# epoch 2, step 11750/55000, batch loss = 0.00
# epoch 2, step 12000/55000, batch loss = 0.05
# epoch 2, step 12250/55000, batch loss = 0.15
# epoch 2, step 12500/55000, batch loss = 0.10
# Train accuracy = 98.49
# epoch 2, step 12750/55000, batch loss = 0.08
# epoch 2, step 13000/55000, batch loss = 0.01
# epoch 2, step 13250/55000, batch loss = 0.02
# epoch 2, step 13500/55000, batch loss = 0.04
# epoch 2, step 13750/55000, batch loss = 0.05
# epoch 2, step 14000/55000, batch loss = 0.02
# epoch 2, step 14250/55000, batch loss = 0.02
# epoch 2, step 14500/55000, batch loss = 0.07
# epoch 2, step 14750/55000, batch loss = 0.01
# epoch 2, step 15000/55000, batch loss = 0.05
# Train accuracy = 98.52
# epoch 2, step 15250/55000, batch loss = 0.02
# epoch 2, step 15500/55000, batch loss = 0.01
# epoch 2, step 15750/55000, batch loss = 0.00
# epoch 2, step 16000/55000, batch loss = 0.06
# epoch 2, step 16250/55000, batch loss = 0.11
# epoch 2, step 16500/55000, batch loss = 0.00
# epoch 2, step 16750/55000, batch loss = 0.05
# epoch 2, step 17000/55000, batch loss = 0.01
# epoch 2, step 17250/55000, batch loss = 0.05
# epoch 2, step 17500/55000, batch loss = 0.11
# Train accuracy = 98.53
# epoch 2, step 17750/55000, batch loss = 0.09
# epoch 2, step 18000/55000, batch loss = 0.09
# epoch 2, step 18250/55000, batch loss = 0.05
# epoch 2, step 18500/55000, batch loss = 0.01
# epoch 2, step 18750/55000, batch loss = 0.02
# epoch 2, step 19000/55000, batch loss = 0.01
# epoch 2, step 19250/55000, batch loss = 0.05
# epoch 2, step 19500/55000, batch loss = 0.01
# epoch 2, step 19750/55000, batch loss = 0.03
# epoch 2, step 20000/55000, batch loss = 0.01
# Train accuracy = 98.55
# epoch 2, step 20250/55000, batch loss = 0.06
# epoch 2, step 20500/55000, batch loss = 0.14
# epoch 2, step 20750/55000, batch loss = 0.02
# epoch 2, step 21000/55000, batch loss = 0.05
# epoch 2, step 21250/55000, batch loss = 0.09
# epoch 2, step 21500/55000, batch loss = 0.02
# epoch 2, step 21750/55000, batch loss = 0.01
# epoch 2, step 22000/55000, batch loss = 0.06
# epoch 2, step 22250/55000, batch loss = 0.02
# epoch 2, step 22500/55000, batch loss = 0.14
# Train accuracy = 98.55
# epoch 2, step 22750/55000, batch loss = 0.01
# epoch 2, step 23000/55000, batch loss = 0.02
# epoch 2, step 23250/55000, batch loss = 0.00
# epoch 2, step 23500/55000, batch loss = 0.02
# epoch 2, step 23750/55000, batch loss = 0.03
# epoch 2, step 24000/55000, batch loss = 0.19
# epoch 2, step 24250/55000, batch loss = 0.25
# epoch 2, step 24500/55000, batch loss = 0.04
# epoch 2, step 24750/55000, batch loss = 0.00
# epoch 2, step 25000/55000, batch loss = 0.01
# Train accuracy = 98.57
# epoch 2, step 25250/55000, batch loss = 0.01
# epoch 2, step 25500/55000, batch loss = 0.06
# epoch 2, step 25750/55000, batch loss = 0.01
# epoch 2, step 26000/55000, batch loss = 0.01
# epoch 2, step 26250/55000, batch loss = 0.13
# epoch 2, step 26500/55000, batch loss = 0.01
# epoch 2, step 26750/55000, batch loss = 0.05
# epoch 2, step 27000/55000, batch loss = 0.01
# epoch 2, step 27250/55000, batch loss = 0.21
# epoch 2, step 27500/55000, batch loss = 0.15
# Train accuracy = 98.58
# epoch 2, step 27750/55000, batch loss = 0.02
# epoch 2, step 28000/55000, batch loss = 0.06
# epoch 2, step 28250/55000, batch loss = 0.08
# epoch 2, step 28500/55000, batch loss = 0.03
# epoch 2, step 28750/55000, batch loss = 0.00
# epoch 2, step 29000/55000, batch loss = 0.04
# epoch 2, step 29250/55000, batch loss = 0.00
# epoch 2, step 29500/55000, batch loss = 0.01
# epoch 2, step 29750/55000, batch loss = 0.00
# epoch 2, step 30000/55000, batch loss = 0.04
# Train accuracy = 98.62
# epoch 2, step 30250/55000, batch loss = 0.01
# epoch 2, step 30500/55000, batch loss = 0.04
# epoch 2, step 30750/55000, batch loss = 0.08
# epoch 2, step 31000/55000, batch loss = 0.01
# epoch 2, step 31250/55000, batch loss = 0.01
# epoch 2, step 31500/55000, batch loss = 0.01
# epoch 2, step 31750/55000, batch loss = 0.00
# epoch 2, step 32000/55000, batch loss = 0.03
# epoch 2, step 32250/55000, batch loss = 0.02
# epoch 2, step 32500/55000, batch loss = 0.08
# Train accuracy = 98.60
# epoch 2, step 32750/55000, batch loss = 0.12
# epoch 2, step 33000/55000, batch loss = 0.12
# epoch 2, step 33250/55000, batch loss = 0.15
# epoch 2, step 33500/55000, batch loss = 0.01
# epoch 2, step 33750/55000, batch loss = 0.03
# epoch 2, step 34000/55000, batch loss = 0.00
# epoch 2, step 34250/55000, batch loss = 0.00
# epoch 2, step 34500/55000, batch loss = 0.06
# epoch 2, step 34750/55000, batch loss = 0.29
# epoch 2, step 35000/55000, batch loss = 0.04
# Train accuracy = 98.57
# epoch 2, step 35250/55000, batch loss = 0.11
# epoch 2, step 35500/55000, batch loss = 0.01
# epoch 2, step 35750/55000, batch loss = 0.02
# epoch 2, step 36000/55000, batch loss = 0.07
# epoch 2, step 36250/55000, batch loss = 0.03
# epoch 2, step 36500/55000, batch loss = 0.02
# epoch 2, step 36750/55000, batch loss = 0.02
# epoch 2, step 37000/55000, batch loss = 0.15
# epoch 2, step 37250/55000, batch loss = 0.05
# epoch 2, step 37500/55000, batch loss = 0.04
# Train accuracy = 98.57
# epoch 2, step 37750/55000, batch loss = 0.02
# epoch 2, step 38000/55000, batch loss = 0.02
# epoch 2, step 38250/55000, batch loss = 0.01
# epoch 2, step 38500/55000, batch loss = 0.03
# epoch 2, step 38750/55000, batch loss = 0.03
# epoch 2, step 39000/55000, batch loss = 0.04
# epoch 2, step 39250/55000, batch loss = 0.05
# epoch 2, step 39500/55000, batch loss = 0.06
# epoch 2, step 39750/55000, batch loss = 0.01
# epoch 2, step 40000/55000, batch loss = 0.01
# Train accuracy = 98.58
# epoch 2, step 40250/55000, batch loss = 0.00
# epoch 2, step 40500/55000, batch loss = 0.05
# epoch 2, step 40750/55000, batch loss = 0.05
# epoch 2, step 41000/55000, batch loss = 0.01
# epoch 2, step 41250/55000, batch loss = 0.02
# epoch 2, step 41500/55000, batch loss = 0.06
# epoch 2, step 41750/55000, batch loss = 0.03
# epoch 2, step 42000/55000, batch loss = 0.01
# epoch 2, step 42250/55000, batch loss = 0.08
# epoch 2, step 42500/55000, batch loss = 0.04
# Train accuracy = 98.59
# epoch 2, step 42750/55000, batch loss = 0.00
# epoch 2, step 43000/55000, batch loss = 0.02
# epoch 2, step 43250/55000, batch loss = 0.01
# epoch 2, step 43500/55000, batch loss = 0.02
# epoch 2, step 43750/55000, batch loss = 0.03
# epoch 2, step 44000/55000, batch loss = 0.02
# epoch 2, step 44250/55000, batch loss = 0.00
# epoch 2, step 44500/55000, batch loss = 0.00
# epoch 2, step 44750/55000, batch loss = 0.19
# epoch 2, step 45000/55000, batch loss = 0.02
# Train accuracy = 98.61
# epoch 2, step 45250/55000, batch loss = 0.01
# epoch 2, step 45500/55000, batch loss = 0.03
# epoch 2, step 45750/55000, batch loss = 0.08
# epoch 2, step 46000/55000, batch loss = 0.03
# epoch 2, step 46250/55000, batch loss = 0.00
# epoch 2, step 46500/55000, batch loss = 0.02
# epoch 2, step 46750/55000, batch loss = 0.10
# epoch 2, step 47000/55000, batch loss = 0.01
# epoch 2, step 47250/55000, batch loss = 0.00
# epoch 2, step 47500/55000, batch loss = 0.05
# Train accuracy = 98.61
# epoch 2, step 47750/55000, batch loss = 0.01
# epoch 2, step 48000/55000, batch loss = 0.01
# epoch 2, step 48250/55000, batch loss = 0.01
# epoch 2, step 48500/55000, batch loss = 0.00
# epoch 2, step 48750/55000, batch loss = 0.03
# epoch 2, step 49000/55000, batch loss = 0.08
# epoch 2, step 49250/55000, batch loss = 0.00
# epoch 2, step 49500/55000, batch loss = 0.02
# epoch 2, step 49750/55000, batch loss = 0.01
# epoch 2, step 50000/55000, batch loss = 0.01
# Train accuracy = 98.62
# epoch 2, step 50250/55000, batch loss = 0.02
# epoch 2, step 50500/55000, batch loss = 0.01
# epoch 2, step 50750/55000, batch loss = 0.09
# epoch 2, step 51000/55000, batch loss = 0.05
# epoch 2, step 51250/55000, batch loss = 0.13
# epoch 2, step 51500/55000, batch loss = 0.03
# epoch 2, step 51750/55000, batch loss = 0.10
# epoch 2, step 52000/55000, batch loss = 0.02
# epoch 2, step 52250/55000, batch loss = 0.01
# epoch 2, step 52500/55000, batch loss = 0.11
# Train accuracy = 98.62
# epoch 2, step 52750/55000, batch loss = 0.03
# epoch 2, step 53000/55000, batch loss = 0.00
# epoch 2, step 53250/55000, batch loss = 0.02
# epoch 2, step 53500/55000, batch loss = 0.03
# epoch 2, step 53750/55000, batch loss = 0.01
# epoch 2, step 54000/55000, batch loss = 0.07
# epoch 2, step 54250/55000, batch loss = 0.09
# epoch 2, step 54500/55000, batch loss = 0.08
# epoch 2, step 54750/55000, batch loss = 0.00
# Train accuracy = 98.62
#
# Running evaluation:  Validation
# Validation accuracy = 98.90
# Validation avg loss = 0.04
#
# epoch 3, step 0/55000, batch loss = 0.01
# epoch 3, step 250/55000, batch loss = 0.00
# epoch 3, step 500/55000, batch loss = 0.01
# epoch 3, step 750/55000, batch loss = 0.01
# epoch 3, step 1000/55000, batch loss = 0.02
# epoch 3, step 1250/55000, batch loss = 0.06
# epoch 3, step 1500/55000, batch loss = 0.01
# epoch 3, step 1750/55000, batch loss = 0.01
# epoch 3, step 2000/55000, batch loss = 0.00
# epoch 3, step 2250/55000, batch loss = 0.00
# epoch 3, step 2500/55000, batch loss = 0.00
# Train accuracy = 99.25
# epoch 3, step 2750/55000, batch loss = 0.01
# epoch 3, step 3000/55000, batch loss = 0.01
# epoch 3, step 3250/55000, batch loss = 0.02
# epoch 3, step 3500/55000, batch loss = 0.00
# epoch 3, step 3750/55000, batch loss = 0.01
# epoch 3, step 4000/55000, batch loss = 0.09
# epoch 3, step 4250/55000, batch loss = 0.01
# epoch 3, step 4500/55000, batch loss = 0.04
# epoch 3, step 4750/55000, batch loss = 0.00
# epoch 3, step 5000/55000, batch loss = 0.05
# Train accuracy = 99.35
# epoch 3, step 5250/55000, batch loss = 0.08
# epoch 3, step 5500/55000, batch loss = 0.00
# epoch 3, step 5750/55000, batch loss = 0.01
# epoch 3, step 6000/55000, batch loss = 0.03
# epoch 3, step 6250/55000, batch loss = 0.05
# epoch 3, step 6500/55000, batch loss = 0.04
# epoch 3, step 6750/55000, batch loss = 0.03
# epoch 3, step 7000/55000, batch loss = 0.01
# epoch 3, step 7250/55000, batch loss = 0.01
# epoch 3, step 7500/55000, batch loss = 0.01
# Train accuracy = 99.31
# epoch 3, step 7750/55000, batch loss = 0.00
# epoch 3, step 8000/55000, batch loss = 0.01
# epoch 3, step 8250/55000, batch loss = 0.02
# epoch 3, step 8500/55000, batch loss = 0.02
# epoch 3, step 8750/55000, batch loss = 0.00
# epoch 3, step 9000/55000, batch loss = 0.00
# epoch 3, step 9250/55000, batch loss = 0.10
# epoch 3, step 9500/55000, batch loss = 0.01
# epoch 3, step 9750/55000, batch loss = 0.00
# epoch 3, step 10000/55000, batch loss = 0.00
# Train accuracy = 99.25
# epoch 3, step 10250/55000, batch loss = 0.00
# epoch 3, step 10500/55000, batch loss = 0.01
# epoch 3, step 10750/55000, batch loss = 0.01
# epoch 3, step 11000/55000, batch loss = 0.01
# epoch 3, step 11250/55000, batch loss = 0.01
# epoch 3, step 11500/55000, batch loss = 0.05
# epoch 3, step 11750/55000, batch loss = 0.07
# epoch 3, step 12000/55000, batch loss = 0.09
# epoch 3, step 12250/55000, batch loss = 0.08
# epoch 3, step 12500/55000, batch loss = 0.04
# Train accuracy = 99.21
# epoch 3, step 12750/55000, batch loss = 0.01
# epoch 3, step 13000/55000, batch loss = 0.01
# epoch 3, step 13250/55000, batch loss = 0.01
# epoch 3, step 13500/55000, batch loss = 0.00
# epoch 3, step 13750/55000, batch loss = 0.02
# epoch 3, step 14000/55000, batch loss = 0.01
# epoch 3, step 14250/55000, batch loss = 0.03
# epoch 3, step 14500/55000, batch loss = 0.01
# epoch 3, step 14750/55000, batch loss = 0.11
# epoch 3, step 15000/55000, batch loss = 0.00
# Train accuracy = 99.20
# epoch 3, step 15250/55000, batch loss = 0.02
# epoch 3, step 15500/55000, batch loss = 0.02
# epoch 3, step 15750/55000, batch loss = 0.02
# epoch 3, step 16000/55000, batch loss = 0.02
# epoch 3, step 16250/55000, batch loss = 0.01
# epoch 3, step 16500/55000, batch loss = 0.01
# epoch 3, step 16750/55000, batch loss = 0.00
# epoch 3, step 17000/55000, batch loss = 0.01
# epoch 3, step 17250/55000, batch loss = 0.02
# epoch 3, step 17500/55000, batch loss = 0.02
# Train accuracy = 99.21
# epoch 3, step 17750/55000, batch loss = 0.00
# epoch 3, step 18000/55000, batch loss = 0.03
# epoch 3, step 18250/55000, batch loss = 0.01
# epoch 3, step 18500/55000, batch loss = 0.10
# epoch 3, step 18750/55000, batch loss = 0.07
# epoch 3, step 19000/55000, batch loss = 0.00
# epoch 3, step 19250/55000, batch loss = 0.00
# epoch 3, step 19500/55000, batch loss = 0.04
# epoch 3, step 19750/55000, batch loss = 0.01
# epoch 3, step 20000/55000, batch loss = 0.02
# Train accuracy = 99.21
# epoch 3, step 20250/55000, batch loss = 0.01
# epoch 3, step 20500/55000, batch loss = 0.02
# epoch 3, step 20750/55000, batch loss = 0.02
# epoch 3, step 21000/55000, batch loss = 0.01
# epoch 3, step 21250/55000, batch loss = 0.00
# epoch 3, step 21500/55000, batch loss = 0.00
# epoch 3, step 21750/55000, batch loss = 0.16
# epoch 3, step 22000/55000, batch loss = 0.01
# epoch 3, step 22250/55000, batch loss = 0.01
# epoch 3, step 22500/55000, batch loss = 0.01
# Train accuracy = 99.26
# epoch 3, step 22750/55000, batch loss = 0.01
# epoch 3, step 23000/55000, batch loss = 0.03
# epoch 3, step 23250/55000, batch loss = 0.01
# epoch 3, step 23500/55000, batch loss = 0.00
# epoch 3, step 23750/55000, batch loss = 0.01
# epoch 3, step 24000/55000, batch loss = 0.00
# epoch 3, step 24250/55000, batch loss = 0.01
# epoch 3, step 24500/55000, batch loss = 0.10
# epoch 3, step 24750/55000, batch loss = 0.00
# epoch 3, step 25000/55000, batch loss = 0.08
# Train accuracy = 99.28
# epoch 3, step 25250/55000, batch loss = 0.03
# epoch 3, step 25500/55000, batch loss = 0.02
# epoch 3, step 25750/55000, batch loss = 0.00
# epoch 3, step 26000/55000, batch loss = 0.04
# epoch 3, step 26250/55000, batch loss = 0.00
# epoch 3, step 26500/55000, batch loss = 0.07
# epoch 3, step 26750/55000, batch loss = 0.01
# epoch 3, step 27000/55000, batch loss = 0.02
# epoch 3, step 27250/55000, batch loss = 0.00
# epoch 3, step 27500/55000, batch loss = 0.02
# Train accuracy = 99.28
# epoch 3, step 27750/55000, batch loss = 0.01
# epoch 3, step 28000/55000, batch loss = 0.02
# epoch 3, step 28250/55000, batch loss = 0.01
# epoch 3, step 28500/55000, batch loss = 0.00
# epoch 3, step 28750/55000, batch loss = 0.00
# epoch 3, step 29000/55000, batch loss = 0.00
# epoch 3, step 29250/55000, batch loss = 0.01
# epoch 3, step 29500/55000, batch loss = 0.02
# epoch 3, step 29750/55000, batch loss = 0.01
# epoch 3, step 30000/55000, batch loss = 0.09
# Train accuracy = 99.31
# epoch 3, step 30250/55000, batch loss = 0.01
# epoch 3, step 30500/55000, batch loss = 0.02
# epoch 3, step 30750/55000, batch loss = 0.02
# epoch 3, step 31000/55000, batch loss = 0.00
# epoch 3, step 31250/55000, batch loss = 0.01
# epoch 3, step 31500/55000, batch loss = 0.03
# epoch 3, step 31750/55000, batch loss = 0.01
# epoch 3, step 32000/55000, batch loss = 0.01
# epoch 3, step 32250/55000, batch loss = 0.03
# epoch 3, step 32500/55000, batch loss = 0.01
# Train accuracy = 99.31
# epoch 3, step 32750/55000, batch loss = 0.07
# epoch 3, step 33000/55000, batch loss = 0.02
# epoch 3, step 33250/55000, batch loss = 0.00
# epoch 3, step 33500/55000, batch loss = 0.00
# epoch 3, step 33750/55000, batch loss = 0.04
# epoch 3, step 34000/55000, batch loss = 0.00
# epoch 3, step 34250/55000, batch loss = 0.00
# epoch 3, step 34500/55000, batch loss = 0.01
# epoch 3, step 34750/55000, batch loss = 0.00
# epoch 3, step 35000/55000, batch loss = 0.02
# Train accuracy = 99.32
# epoch 3, step 35250/55000, batch loss = 0.01
# epoch 3, step 35500/55000, batch loss = 0.00
# epoch 3, step 35750/55000, batch loss = 0.02
# epoch 3, step 36000/55000, batch loss = 0.06
# epoch 3, step 36250/55000, batch loss = 0.00
# epoch 3, step 36500/55000, batch loss = 0.00
# epoch 3, step 36750/55000, batch loss = 0.01
# epoch 3, step 37000/55000, batch loss = 0.04
# epoch 3, step 37250/55000, batch loss = 0.01
# epoch 3, step 37500/55000, batch loss = 0.03
# Train accuracy = 99.31
# epoch 3, step 37750/55000, batch loss = 0.00
# epoch 3, step 38000/55000, batch loss = 0.00
# epoch 3, step 38250/55000, batch loss = 0.01
# epoch 3, step 38500/55000, batch loss = 0.00
# epoch 3, step 38750/55000, batch loss = 0.00
# epoch 3, step 39000/55000, batch loss = 0.02
# epoch 3, step 39250/55000, batch loss = 0.01
# epoch 3, step 39500/55000, batch loss = 0.00
# epoch 3, step 39750/55000, batch loss = 0.01
# epoch 3, step 40000/55000, batch loss = 0.01
# Train accuracy = 99.33
# epoch 3, step 40250/55000, batch loss = 0.02
# epoch 3, step 40500/55000, batch loss = 0.01
# epoch 3, step 40750/55000, batch loss = 0.05
# epoch 3, step 41000/55000, batch loss = 0.04
# epoch 3, step 41250/55000, batch loss = 0.01
# epoch 3, step 41500/55000, batch loss = 0.00
# epoch 3, step 41750/55000, batch loss = 0.01
# epoch 3, step 42000/55000, batch loss = 0.01
# epoch 3, step 42250/55000, batch loss = 0.00
# epoch 3, step 42500/55000, batch loss = 0.00
# Train accuracy = 99.34
# epoch 3, step 42750/55000, batch loss = 0.00
# epoch 3, step 43000/55000, batch loss = 0.00
# epoch 3, step 43250/55000, batch loss = 0.02
# epoch 3, step 43500/55000, batch loss = 0.00
# epoch 3, step 43750/55000, batch loss = 0.01
# epoch 3, step 44000/55000, batch loss = 0.01
# epoch 3, step 44250/55000, batch loss = 0.01
# epoch 3, step 44500/55000, batch loss = 0.01
# epoch 3, step 44750/55000, batch loss = 0.03
# epoch 3, step 45000/55000, batch loss = 0.07
# Train accuracy = 99.34
# epoch 3, step 45250/55000, batch loss = 0.01
# epoch 3, step 45500/55000, batch loss = 0.02
# epoch 3, step 45750/55000, batch loss = 0.03
# epoch 3, step 46000/55000, batch loss = 0.00
# epoch 3, step 46250/55000, batch loss = 0.00
# epoch 3, step 46500/55000, batch loss = 0.02
# epoch 3, step 46750/55000, batch loss = 0.00
# epoch 3, step 47000/55000, batch loss = 0.05
# epoch 3, step 47250/55000, batch loss = 0.00
# epoch 3, step 47500/55000, batch loss = 0.01
# Train accuracy = 99.34
# epoch 3, step 47750/55000, batch loss = 0.00
# epoch 3, step 48000/55000, batch loss = 0.00
# epoch 3, step 48250/55000, batch loss = 0.00
# epoch 3, step 48500/55000, batch loss = 0.01
# epoch 3, step 48750/55000, batch loss = 0.00
# epoch 3, step 49000/55000, batch loss = 0.00
# epoch 3, step 49250/55000, batch loss = 0.02
# epoch 3, step 49500/55000, batch loss = 0.00
# epoch 3, step 49750/55000, batch loss = 0.00
# epoch 3, step 50000/55000, batch loss = 0.00
# Train accuracy = 99.35
# epoch 3, step 50250/55000, batch loss = 0.04
# epoch 3, step 50500/55000, batch loss = 0.04
# epoch 3, step 50750/55000, batch loss = 0.01
# epoch 3, step 51000/55000, batch loss = 0.04
# epoch 3, step 51250/55000, batch loss = 0.01
# epoch 3, step 51500/55000, batch loss = 0.02
# epoch 3, step 51750/55000, batch loss = 0.01
# epoch 3, step 52000/55000, batch loss = 0.00
# epoch 3, step 52250/55000, batch loss = 0.01
# epoch 3, step 52500/55000, batch loss = 0.00
# Train accuracy = 99.35
# epoch 3, step 52750/55000, batch loss = 0.05
# epoch 3, step 53000/55000, batch loss = 0.01
# epoch 3, step 53250/55000, batch loss = 0.00
# epoch 3, step 53500/55000, batch loss = 0.09
# epoch 3, step 53750/55000, batch loss = 0.03
# epoch 3, step 54000/55000, batch loss = 0.01
# epoch 3, step 54250/55000, batch loss = 0.00
# epoch 3, step 54500/55000, batch loss = 0.00
# epoch 3, step 54750/55000, batch loss = 0.01
# Train accuracy = 99.36
#
# Running evaluation:  Validation
# Validation accuracy = 99.08
# Validation avg loss = 0.03
#
# epoch 4, step 0/55000, batch loss = 0.01
# epoch 4, step 250/55000, batch loss = 0.00
# epoch 4, step 500/55000, batch loss = 0.00
# epoch 4, step 750/55000, batch loss = 0.00
# epoch 4, step 1000/55000, batch loss = 0.06
# epoch 4, step 1250/55000, batch loss = 0.03
# epoch 4, step 1500/55000, batch loss = 0.03
# epoch 4, step 1750/55000, batch loss = 0.00
# epoch 4, step 2000/55000, batch loss = 0.01
# epoch 4, step 2250/55000, batch loss = 0.05
# epoch 4, step 2500/55000, batch loss = 0.01
# Train accuracy = 99.53
# epoch 4, step 2750/55000, batch loss = 0.00
# epoch 4, step 3000/55000, batch loss = 0.01
# epoch 4, step 3250/55000, batch loss = 0.10
# epoch 4, step 3500/55000, batch loss = 0.02
# epoch 4, step 3750/55000, batch loss = 0.01
# epoch 4, step 4000/55000, batch loss = 0.01
# epoch 4, step 4250/55000, batch loss = 0.01
# epoch 4, step 4500/55000, batch loss = 0.02
# epoch 4, step 4750/55000, batch loss = 0.00
# epoch 4, step 5000/55000, batch loss = 0.12
# Train accuracy = 99.50
# epoch 4, step 5250/55000, batch loss = 0.05
# epoch 4, step 5500/55000, batch loss = 0.03
# epoch 4, step 5750/55000, batch loss = 0.00
# epoch 4, step 6000/55000, batch loss = 0.00
# epoch 4, step 6250/55000, batch loss = 0.00
# epoch 4, step 6500/55000, batch loss = 0.00
# epoch 4, step 6750/55000, batch loss = 0.02
# epoch 4, step 7000/55000, batch loss = 0.00
# epoch 4, step 7250/55000, batch loss = 0.00
# epoch 4, step 7500/55000, batch loss = 0.04
# Train accuracy = 99.48
# epoch 4, step 7750/55000, batch loss = 0.03
# epoch 4, step 8000/55000, batch loss = 0.02
# epoch 4, step 8250/55000, batch loss = 0.06
# epoch 4, step 8500/55000, batch loss = 0.00
# epoch 4, step 8750/55000, batch loss = 0.01
# epoch 4, step 9000/55000, batch loss = 0.01
# epoch 4, step 9250/55000, batch loss = 0.04
# epoch 4, step 9500/55000, batch loss = 0.02
# epoch 4, step 9750/55000, batch loss = 0.01
# epoch 4, step 10000/55000, batch loss = 0.00
# Train accuracy = 99.43
# epoch 4, step 10250/55000, batch loss = 0.01
# epoch 4, step 10500/55000, batch loss = 0.00
# epoch 4, step 10750/55000, batch loss = 0.01
# epoch 4, step 11000/55000, batch loss = 0.02
# epoch 4, step 11250/55000, batch loss = 0.01
# epoch 4, step 11500/55000, batch loss = 0.00
# epoch 4, step 11750/55000, batch loss = 0.01
# epoch 4, step 12000/55000, batch loss = 0.05
# epoch 4, step 12250/55000, batch loss = 0.00
# epoch 4, step 12500/55000, batch loss = 0.02
# Train accuracy = 99.43
# epoch 4, step 12750/55000, batch loss = 0.00
# epoch 4, step 13000/55000, batch loss = 0.14
# epoch 4, step 13250/55000, batch loss = 0.02
# epoch 4, step 13500/55000, batch loss = 0.08
# epoch 4, step 13750/55000, batch loss = 0.01
# epoch 4, step 14000/55000, batch loss = 0.01
# epoch 4, step 14250/55000, batch loss = 0.07
# epoch 4, step 14500/55000, batch loss = 0.01
# epoch 4, step 14750/55000, batch loss = 0.00
# epoch 4, step 15000/55000, batch loss = 0.01
# Train accuracy = 99.41
# epoch 4, step 15250/55000, batch loss = 0.11
# epoch 4, step 15500/55000, batch loss = 0.01
# epoch 4, step 15750/55000, batch loss = 0.02
# epoch 4, step 16000/55000, batch loss = 0.01
# epoch 4, step 16250/55000, batch loss = 0.05
# epoch 4, step 16500/55000, batch loss = 0.00
# epoch 4, step 16750/55000, batch loss = 0.01
# epoch 4, step 17000/55000, batch loss = 0.04
# epoch 4, step 17250/55000, batch loss = 0.01
# epoch 4, step 17500/55000, batch loss = 0.03
# Train accuracy = 99.42
# epoch 4, step 17750/55000, batch loss = 0.11
# epoch 4, step 18000/55000, batch loss = 0.04
# epoch 4, step 18250/55000, batch loss = 0.01
# epoch 4, step 18500/55000, batch loss = 0.02
# epoch 4, step 18750/55000, batch loss = 0.01
# epoch 4, step 19000/55000, batch loss = 0.01
# epoch 4, step 19250/55000, batch loss = 0.01
# epoch 4, step 19500/55000, batch loss = 0.00
# epoch 4, step 19750/55000, batch loss = 0.01
# epoch 4, step 20000/55000, batch loss = 0.02
# Train accuracy = 99.40
# epoch 4, step 20250/55000, batch loss = 0.02
# epoch 4, step 20500/55000, batch loss = 0.01
# epoch 4, step 20750/55000, batch loss = 0.00
# epoch 4, step 21000/55000, batch loss = 0.01
# epoch 4, step 21250/55000, batch loss = 0.02
# epoch 4, step 21500/55000, batch loss = 0.00
# epoch 4, step 21750/55000, batch loss = 0.01
# epoch 4, step 22000/55000, batch loss = 0.01
# epoch 4, step 22250/55000, batch loss = 0.00
# epoch 4, step 22500/55000, batch loss = 0.01
# Train accuracy = 99.41
# epoch 4, step 22750/55000, batch loss = 0.02
# epoch 4, step 23000/55000, batch loss = 0.05
# epoch 4, step 23250/55000, batch loss = 0.00
# epoch 4, step 23500/55000, batch loss = 0.00
# epoch 4, step 23750/55000, batch loss = 0.02
# epoch 4, step 24000/55000, batch loss = 0.05
# epoch 4, step 24250/55000, batch loss = 0.00
# epoch 4, step 24500/55000, batch loss = 0.01
# epoch 4, step 24750/55000, batch loss = 0.02
# epoch 4, step 25000/55000, batch loss = 0.01
# Train accuracy = 99.41
# epoch 4, step 25250/55000, batch loss = 0.02
# epoch 4, step 25500/55000, batch loss = 0.00
# epoch 4, step 25750/55000, batch loss = 0.01
# epoch 4, step 26000/55000, batch loss = 0.00
# epoch 4, step 26250/55000, batch loss = 0.01
# epoch 4, step 26500/55000, batch loss = 0.01
# epoch 4, step 26750/55000, batch loss = 0.00
# epoch 4, step 27000/55000, batch loss = 0.01
# epoch 4, step 27250/55000, batch loss = 0.01
# epoch 4, step 27500/55000, batch loss = 0.01
# Train accuracy = 99.42
# epoch 4, step 27750/55000, batch loss = 0.00
# epoch 4, step 28000/55000, batch loss = 0.06
# epoch 4, step 28250/55000, batch loss = 0.01
# epoch 4, step 28500/55000, batch loss = 0.00
# epoch 4, step 28750/55000, batch loss = 0.01
# epoch 4, step 29000/55000, batch loss = 0.01
# epoch 4, step 29250/55000, batch loss = 0.01
# epoch 4, step 29500/55000, batch loss = 0.04
# epoch 4, step 29750/55000, batch loss = 0.01
# epoch 4, step 30000/55000, batch loss = 0.00
# Train accuracy = 99.42
# epoch 4, step 30250/55000, batch loss = 0.00
# epoch 4, step 30500/55000, batch loss = 0.03
# epoch 4, step 30750/55000, batch loss = 0.00
# epoch 4, step 31000/55000, batch loss = 0.05
# epoch 4, step 31250/55000, batch loss = 0.00
# epoch 4, step 31500/55000, batch loss = 0.03
# epoch 4, step 31750/55000, batch loss = 0.02
# epoch 4, step 32000/55000, batch loss = 0.02
# epoch 4, step 32250/55000, batch loss = 0.00
# epoch 4, step 32500/55000, batch loss = 0.01
# Train accuracy = 99.42
# epoch 4, step 32750/55000, batch loss = 0.02
# epoch 4, step 33000/55000, batch loss = 0.16
# epoch 4, step 33250/55000, batch loss = 0.00
# epoch 4, step 33500/55000, batch loss = 0.02
# epoch 4, step 33750/55000, batch loss = 0.02
# epoch 4, step 34000/55000, batch loss = 0.01
# epoch 4, step 34250/55000, batch loss = 0.00
# epoch 4, step 34500/55000, batch loss = 0.03
# epoch 4, step 34750/55000, batch loss = 0.01
# epoch 4, step 35000/55000, batch loss = 0.01
# Train accuracy = 99.41
# epoch 4, step 35250/55000, batch loss = 0.00
# epoch 4, step 35500/55000, batch loss = 0.00
# epoch 4, step 35750/55000, batch loss = 0.00
# epoch 4, step 36000/55000, batch loss = 0.01
# epoch 4, step 36250/55000, batch loss = 0.00
# epoch 4, step 36500/55000, batch loss = 0.01
# epoch 4, step 36750/55000, batch loss = 0.02
# epoch 4, step 37000/55000, batch loss = 0.01
# epoch 4, step 37250/55000, batch loss = 0.07
# epoch 4, step 37500/55000, batch loss = 0.00
# Train accuracy = 99.40
# epoch 4, step 37750/55000, batch loss = 0.05
# epoch 4, step 38000/55000, batch loss = 0.01
# epoch 4, step 38250/55000, batch loss = 0.03
# epoch 4, step 38500/55000, batch loss = 0.02
# epoch 4, step 38750/55000, batch loss = 0.01
# epoch 4, step 39000/55000, batch loss = 0.00
# epoch 4, step 39250/55000, batch loss = 0.00
# epoch 4, step 39500/55000, batch loss = 0.00
# epoch 4, step 39750/55000, batch loss = 0.00
# epoch 4, step 40000/55000, batch loss = 0.00
# Train accuracy = 99.42
# epoch 4, step 40250/55000, batch loss = 0.00
# epoch 4, step 40500/55000, batch loss = 0.00
# epoch 4, step 40750/55000, batch loss = 0.01
# epoch 4, step 41000/55000, batch loss = 0.04
# epoch 4, step 41250/55000, batch loss = 0.02
# epoch 4, step 41500/55000, batch loss = 0.00
# epoch 4, step 41750/55000, batch loss = 0.01
# epoch 4, step 42000/55000, batch loss = 0.07
# epoch 4, step 42250/55000, batch loss = 0.00
# epoch 4, step 42500/55000, batch loss = 0.03
# Train accuracy = 99.42
# epoch 4, step 42750/55000, batch loss = 0.06
# epoch 4, step 43000/55000, batch loss = 0.00
# epoch 4, step 43250/55000, batch loss = 0.02
# epoch 4, step 43500/55000, batch loss = 0.00
# epoch 4, step 43750/55000, batch loss = 0.01
# epoch 4, step 44000/55000, batch loss = 0.04
# epoch 4, step 44250/55000, batch loss = 0.01
# epoch 4, step 44500/55000, batch loss = 0.07
# epoch 4, step 44750/55000, batch loss = 0.00
# epoch 4, step 45000/55000, batch loss = 0.07
# Train accuracy = 99.43
# epoch 4, step 45250/55000, batch loss = 0.09
# epoch 4, step 45500/55000, batch loss = 0.01
# epoch 4, step 45750/55000, batch loss = 0.07
# epoch 4, step 46000/55000, batch loss = 0.01
# epoch 4, step 46250/55000, batch loss = 0.01
# epoch 4, step 46500/55000, batch loss = 0.01
# epoch 4, step 46750/55000, batch loss = 0.00
# epoch 4, step 47000/55000, batch loss = 0.02
# epoch 4, step 47250/55000, batch loss = 0.00
# epoch 4, step 47500/55000, batch loss = 0.01
# Train accuracy = 99.43
# epoch 4, step 47750/55000, batch loss = 0.00
# epoch 4, step 48000/55000, batch loss = 0.03
# epoch 4, step 48250/55000, batch loss = 0.07
# epoch 4, step 48500/55000, batch loss = 0.01
# epoch 4, step 48750/55000, batch loss = 0.00
# epoch 4, step 49000/55000, batch loss = 0.01
# epoch 4, step 49250/55000, batch loss = 0.02
# epoch 4, step 49500/55000, batch loss = 0.01
# epoch 4, step 49750/55000, batch loss = 0.01
# epoch 4, step 50000/55000, batch loss = 0.00
# Train accuracy = 99.43
# epoch 4, step 50250/55000, batch loss = 0.00
# epoch 4, step 50500/55000, batch loss = 0.06
# epoch 4, step 50750/55000, batch loss = 0.00
# epoch 4, step 51000/55000, batch loss = 0.01
# epoch 4, step 51250/55000, batch loss = 0.03
# epoch 4, step 51500/55000, batch loss = 0.01
# epoch 4, step 51750/55000, batch loss = 0.00
# epoch 4, step 52000/55000, batch loss = 0.00
# epoch 4, step 52250/55000, batch loss = 0.02
# epoch 4, step 52500/55000, batch loss = 0.01
# Train accuracy = 99.44
# epoch 4, step 52750/55000, batch loss = 0.01
# epoch 4, step 53000/55000, batch loss = 0.02
# epoch 4, step 53250/55000, batch loss = 0.00
# epoch 4, step 53500/55000, batch loss = 0.02
# epoch 4, step 53750/55000, batch loss = 0.00
# epoch 4, step 54000/55000, batch loss = 0.02
# epoch 4, step 54250/55000, batch loss = 0.00
# epoch 4, step 54500/55000, batch loss = 0.02
# epoch 4, step 54750/55000, batch loss = 0.01
# Train accuracy = 99.45
#
# Running evaluation:  Validation
# Validation accuracy = 99.10
# Validation avg loss = 0.03
#
#
# Running evaluation:  Test
# Test accuracy = 99.14
# Test avg loss = 0.03
